# %%
import pandas as pd;

# %%
benin = pd.read_csv("benin_summary.csv")
sera  = pd.read_csv("seralleon_summary.csv")
togo  = pd.read_csv("togo_summary.csv")

comparison = pd.concat([benin,sera,togo],axis=0)
comparison.index = ['benin','sera','togo']
comparison
# Out:
#        Annual_GHI_kWh  Average_PSH  Diffuse_Fraction_mean  Beam_Ratio_mean  \
# benin     126438.0482   345.459148                    NaN              NaN
# sera      106148.8700   290.024235                    NaN              NaN
# togo      121179.7289   331.092155                    inf         0.288609
#
#        GHI_hourly_std_mean  GHI_daily_std_mean  Avg_Temperature  Avg_Wind  \
# benin            35.071601          323.567167        35.246026  2.121113
# sera             47.148544          291.022831        32.504263  1.146113
# togo             39.339356          313.500239        32.444403  2.368093
#
#        Total_Precip_mm
# benin           1001.2
# sera            2526.0
# togo             726.4

# %%
import pandas as pd;

# %%
benin = pd.read_csv("benin_summary.csv")
sera  = pd.read_csv("seralleon_summary.csv")
togo  = pd.read_csv("togo_summary.csv")

comparison = pd.concat([benin,sera,togo],axis=0)
comparison.index = ['benin','sera','togo']
comparison
# Out:
#        Annual_GHI_kWh  Average_PSH  Diffuse_Fraction_mean  Beam_Ratio_mean  \
# benin     127909.0642   349.478317               0.595858         0.533681
# sera      107436.2025   293.541537               0.684187         0.457917
# togo      121791.3938   332.763371               0.603801         0.560076
#
#        GHI_hourly_std_mean  GHI_daily_std_mean  Avg_Temperature  Avg_Wind  \
# benin            34.985889          321.471222        35.246026  2.121113
# sera             85.648639          287.706340        32.504263  1.146113
# togo             70.118241          298.241880        32.444403  2.368093
#
#        Total_Precip_mm
# benin           1001.2
# sera            2526.0
# togo             726.4
